# %%
import pandas as pd
import sqlite3

# %%
# creating database connection
conn = sqlite3.connect('Inventoryy.db')

# %%
tables= pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table'",conn)
tables
# Out:
#                    name
# 0       begin_inventory
# 1         end_inventory
# 2             purchases
# 3       purchase_prices
# 4                 sales
# 5        vendor_invoice
# 6  vendor_sales_summary

# %%
pd.read_sql("select count(*) from purchases ",conn)
# Out:
#    count(*)
# 0   2372474

# %%
pd.read_sql("select * from sales limit 5 ",conn)
# Out:
#            InventoryId  Store  Brand                 Description        Size  \
# 0  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 1  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 2  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 3  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 4  1_HARDERSFIELD_1005      1   1005     Maker's Mark Combo Pack  375mL 2 Pk
#
#    SalesQuantity  SalesDollars  SalesPrice   SalesDate  Volume  \
# 0              1         16.49       16.49  2024-01-01   750.0
# 1              2         32.98       16.49  2024-01-02   750.0
# 2              1         16.49       16.49  2024-01-03   750.0
# 3              1         14.49       14.49  2024-01-08   750.0
# 4              2         69.98       34.99  2024-01-09   375.0
#
#    Classification  ExciseTax  VendorNo                   VendorName
# ...

# %%
## if i wants to show all the table details together
## tables upor defined h
for tab in tables['name']:
  
    print("-"*50, f"{tab}","-"*50)
    print(pd.read_sql(f"select count(*) from {tab}",conn))
    display( pd.read_sql(f"select * from {tab} limit 5 ",conn))
# Out:
# -------------------------------------------------- begin_inventory --------------------------------------------------
#    count(*)
# 0    206529
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
# 2  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
# 3  1_HARDERSFIELD_63      1  HARDERSFIELD     63   Herradura Reposado Tequila
# 4  1_HARDERSFIELD_72      1  HARDERSFIELD     72         No. 3 London Dry Gin
#
#     Size  onHand  Price   startDate
# 0  750mL       8  12.99  2024-01-01
# 1  750mL       7  10.99  2024-01-01
# 2  750mL       6  36.99  2024-01-01
# 3  750mL       3  38.99  2024-01-01
# 4  750mL       6  34.99  2024-01-01
# -------------------------------------------------- end_inventory --------------------------------------------------
#    count(*)
# ...

# %%
purchaseTab= pd.read_sql("select * from purchases where VendorNumber =60", conn)
print(purchaseTab["Store"].nunique())
print(purchaseTab["Store"].unique())
print(purchaseTab["Brand"].nunique())
print(purchaseTab["Brand"].unique())
print(purchaseTab["PurchasePrice"].unique())
display(purchaseTab)
# Out:
# 41
# [38 10 60 61 41 71  1 66 79 67 32 69 50 33 77 55 48 30 68  8 49 74  2 44
#  76  6 23 56 21  7 15 34 59 73 14  4 54 24 19 81 57]
# 3
# [3979  771 3401]
# [16.27 11.44 11.1 ]
#                InventoryId  Store  Brand          Description   Size  \
# 0        38_GOULCREST_3979     38   3979  Vesica Potato Vodka  1.75L
# 1          10_HORNSEY_3979     10   3979  Vesica Potato Vodka  1.75L
# 2          60_IRRAGIN_3979     60   3979  Vesica Potato Vodka  1.75L
# 3        61_AETHELNEY_3979     61   3979  Vesica Potato Vodka  1.75L
# 4         41_LARNWICK_3979     41   3979  Vesica Potato Vodka  1.75L
# ..                     ...    ...    ...                  ...    ...
# 621  56_BEGGAR'S HOLE_3979     56   3979  Vesica Potato Vodka  1.75L
# 622      32_MOUNTMEND_3979     32   3979  Vesica Potato Vodka  1.75L
# 623      73_DONCASTER_3979     73   3979  Vesica Potato Vodka  1.75L
# 624        2_ASHBORNE_3979      2   3979  Vesica Potato Vodka  1.75L
# ...

# %%
purchaseTab.groupby(["Brand","PurchasePrice"])[["Quantity","Dollars"]].sum()
# Out:
#                      Quantity   Dollars
# Brand PurchasePrice
# 3140  11.19              4640  51921.60
# 5215  9.41               4923  46325.43
# 5255  9.35               6215  58110.25

# %%
purchase_price_Tab= pd.read_sql("select * from purchase_prices ", conn)
display(purchase_price_Tab)
# Out:
#        Brand                   Description  Price    Size Volume  \
# 0         58   Gekkeikan Black & Gold Sake  12.99   750mL    750
# 1         62      Herradura Silver Tequila  36.99   750mL    750
# 2         63    Herradura Reposado Tequila  38.99   750mL    750
# 3         72          No. 3 London Dry Gin  34.99   750mL    750
# 4         75     Three Olives Tomato Vodka  14.99   750mL    750
# ...      ...                           ...    ...     ...    ...
# 12256  44917     Ferreira 10-Yr Tawny Port  24.99   750mL    750
# 12257  44944     Sanford Santa Rita Pnt Nr  22.99   750mL    750
# 12258  45016  Neal One Lane Bridg Cab Svgn  93.99   750mL    750
# 12259  46011       Folonari Pnt Nr Venezie  12.99  1500ml   1500
# 12260  46964     Calera Viognier Mt Harlan  35.99   750mL    750
#
#        Classification  PurchasePrice  VendorNumber  \
# 0                   1           9.28          8320
# 1                   1          28.67          1128
# ...

# %%
print(purchase_price_Tab["Brand"].nunique())
# Out:
# 12261

# %%
purchase_price_Tab.groupby(["VendorNumber","VendorName"])["VendorName"].count()
# Out:
# VendorNumber  VendorName
# 2             IRA GOLDMAN AND WILLIAMS, LLP               2
# 54            AAPER ALCOHOL & CHEMICAL CO                 1
# 60            ADAMBA IMPORTS INTL INC                     3
# 105           ALTAMAR BRANDS LLC                          3
# 200           AMERICAN SPIRITS EXCHANGE                   3
#                                                          ..
# 90059         BLACK COVE BEVERAGES                        1
# 98450         Serralles Usa LLC                          16
# 99166         STARK BREWING COMPANY                       1
# 172662        SWEETWATER FARM                             5
# 173357        TAMWORTH DISTILLING                         4
# Name: VendorName, Length: 136, dtype: int64

# %%
purchase_price_Tab.loc[purchase_price_Tab["VendorNumber"]==98450]
# Out:
#        Brand                   Description  Price    Size Volume  \
# 326     2241              Death's Door Gin  25.99   750mL    750
# 946     4145             Don Q Cristal Rum  19.99  1750mL   1750
# 1725    8543                 Kringle Cream  19.99   750mL    750
# 3731    6877  Original Wondermint Schnapps  18.99   750mL    750
# 3981     262             Don Q Cristal Rum  11.99  1000mL   1000
# 3982     264               Don Q Limon Rum  12.99  1000mL   1000
# 3983     267        Don Q Coco Coconut Rum  12.99  1000mL   1000
# 4432    4139                Don Q Coco Rum  14.99  1750mL   1750
# 4947    5953       Barrow's Intense Ginger  19.99   375mL    375
# 5034    7890       Barrow's Intense Ginger  29.99   750mL    750
# 5789     300                Don Q Gold Rum  18.99  1750mL   1750
# 5805     609                Don Q Gold Rum  10.99   750mL    750
# 7317     266              Don Q Mojito Rum  12.99  1000mL   1000
# ...

# %%
vendorInvoice= pd.read_sql("select * from vendor_invoice where VendorNumber = 4466  limit 3 ",conn)
display(vendorInvoice)
# Out:
#    VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0          4466  AMERICAN VINTAGE BEVERAGE    2024-01-07      8137
# 1          4466  AMERICAN VINTAGE BEVERAGE    2024-01-19      8207
# 2          4466  AMERICAN VINTAGE BEVERAGE    2024-01-18      8307
#
#        PODate     PayDate  Quantity  Dollars  Freight Approval
# 0  2023-12-22  2024-02-21        15   140.55     8.57     None
# 1  2023-12-27  2024-02-26       335  3142.33    16.97     None
# 2  2024-01-03  2024-02-18        41   383.35     1.99     None

# %%
vendorInvoice["Quantity"].sum()  ## sum of the quantity in purchase table
# Out:
# np.int64(15778)

# %%
purchaseTab["PONumber"].nunique()
# Out:
# 55

# %%
vendorInvoice["PONumber"].nunique()
# Out:
# 10

# %%
vendorInvoice.columns
# Out:
# Index(['VendorNumber', 'VendorName', 'InvoiceDate', 'PONumber', 'PODate',
#        'PayDate', 'Quantity', 'Dollars', 'Freight', 'Approval'],
#       dtype='object')

# %%
purchase_price_Tab.columns
# Out:
# Index(['Brand', 'Description', 'Price', 'Size', 'Volume', 'Classification',
#        'PurchasePrice', 'VendorNumber', 'VendorName'],
#       dtype='object')

# %%
purchaseTab.columns
# Out:
# Index(['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'VendorNumber',
#        'VendorName', 'PONumber', 'PODate', 'ReceivingDate', 'InvoiceDate',
#        'PayDate', 'PurchasePrice', 'Quantity', 'Dollars', 'Classification'],
#       dtype='object')

# %%
saleTab= pd.read_sql("select * from sales where VendorNo= 4466  ",conn)
display(saleTab)
# Out:
#               InventoryId  Store  Brand                   Description   Size  \
# 0     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 1     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 2     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 3     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 4     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# ...                   ...    ...    ...                           ...    ...
# 9448     9_BLACKPOOL_5215      9   5215  TGI Fridays Long Island Iced  1.75L
# 9449     9_BLACKPOOL_5255      9   5255  TGI Fridays Ultimte Mudslide  1.75L
# 9450     9_BLACKPOOL_5255      9   5255  TGI Fridays Ultimte Mudslide  1.75L
# 9451     9_BLACKPOOL_5255      9   5255  TGI Fridays Ultimte Mudslide  1.75L
# 9452     9_BLACKPOOL_5255      9   5255  TGI Fridays Ultimte Mudslide  1.75L
#
# ...

# %%
saleTab.groupby("Brand")[["SalesQuantity","SalesDollars"]].sum()
# Out:
#        SalesQuantity  SalesDollars
# Brand
# 3140            3890      50531.10
# 5215            4651      60416.49
# 5255            6096      79187.04

# %%
purchaseTab.groupby(["Brand","PurchasePrice"])[["Quantity","Dollars"]].sum()
# Out:
#                      Quantity   Dollars
# Brand PurchasePrice
# 3140  11.19              4640  51921.60
# 5215  9.41               4923  46325.43
# 5255  9.35               6215  58110.25

# %%
vendorInvoice.columns
# Out:
# Index(['VendorNumber', 'VendorName', 'InvoiceDate', 'PONumber', 'PODate',
#        'PayDate', 'Quantity', 'Dollars', 'Freight', 'Approval'],
#       dtype='object')

# %%
freight_summary= pd.read_sql("""select VendorName,
                             VendorNumber,
                             sum(Freight) as freight_cost
                             from vendor_invoice 
                             group by  VendorName,VendorNumber""",conn)

# %%
freight_summary
# Out:
#                           VendorName  VendorNumber  freight_cost
# 0        AAPER ALCOHOL & CHEMICAL CO            54          0.48
# 1        ADAMBA IMPORTS INTL INC                60        367.52
# 2    ALISA CARR BEVERAGES                     1703        172.00
# 3        ALTAMAR BRANDS LLC                    105         62.39
# 4        AMERICAN SPIRITS EXCHANGE             200          6.19
# ..                               ...           ...           ...
# 124      WEIN BAUER INC                       9622        222.23
# 125      WESTERN SPIRITS BEVERAGE CO          9625       1933.19
# 126      WILLIAM GRANT & SONS INC             3664      30234.42
# 127      WINE GROUP INC                       9815      27100.41
# 128      ZORVINO VINEYARDS                   90058        448.68
#
# [129 rows x 3 columns]

# %%
freight_summary.loc[freight_summary["VendorNumber"]==4466]
# Out:
#                     VendorName  VendorNumber  freight_cost
# 5  AMERICAN VINTAGE BEVERAGE            4466        793.91

# %%
print(purchaseTab.columns)
print(purchase_price_Tab.columns)
# Out:
# Index(['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'VendorNumber',
#        'VendorName', 'PONumber', 'PODate', 'ReceivingDate', 'InvoiceDate',
#        'PayDate', 'PurchasePrice', 'Quantity', 'Dollars', 'Classification'],
#       dtype='object')
# Index(['Brand', 'Description', 'Price', 'Size', 'Volume', 'Classification',
#        'PurchasePrice', 'VendorNumber', 'VendorName'],
#       dtype='object')

# %%
pd.read_sql_query(""" SELECT 
       p.VendorNumber,
       p.VendorName,
       p.Brand ,
       p.PurchasePrice ,
       pp.Volume,
       pp.Price as ActualPrice,
       SUM(p.Quantity) as TotalPurchaseQuantity,
       SUM(p.Dollars) as TotalPurchaseDollars
       FROM purchases as p
       JOIN
       purchase_prices as pp
       ON p.Brand= pp.Brand
       WHERE p.PurchasePrice>0
       GROUP BY p.VendorNumber,p.VendorName,p.Brand ,p.PurchasePrice ,pp.Volume,pp.Price
       ORDER BY TotalPurchaseDollars""", conn)
# Out:
#        VendorNumber                   VendorName  Brand  PurchasePrice Volume  \
# 0              7245  PROXIMO SPIRITS INC.          3065           0.71     50
# 1              3960  DIAGEO NORTH AMERICA INC      6127           1.47    200
# 2              3924  HEAVEN HILL DISTILLERIES      9123           0.74     50
# 3              8004  SAZERAC CO INC                5683           0.39     50
# 4              9815  WINE GROUP INC                8527           1.32    750
# ...             ...                          ...    ...            ...    ...
# 10687          3960  DIAGEO NORTH AMERICA INC      3545          21.89   1750
# 10688          3960  DIAGEO NORTH AMERICA INC      4261          16.17   1750
# 10689         17035  PERNOD RICARD USA             8068          18.24   1750
# 10690          4425        MARTIGNETTI COMPANIES   3405          23.19   1750
# 10691          1128  BROWN-FORMAN CORP             1233          26.27   1750
#
# ...

# %%
saleTab.columns
# Out:
# Index(['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'SalesQuantity',
#        'SalesDollars', 'SalesPrice', 'SalesDate', 'Volume', 'Classification',
#        'ExciseTax', 'VendorNo', 'VendorName'],
#       dtype='object')

# %%
pd.read_sql_query(""" SELECT
        VendorNo,
        Brand ,
        SUM(SalesQuantity) AS TotalSalesQuantity,
        SUM(SalesDollars)  AS TotalSalesDollars,
        SUM(SalesPrice) AS TotalSalesPrice,
        SUM(ExciseTax) AS TotalExciseTax
        FROM sales
        GROUP BY VendorNo,Brand 
        ORDER BY TotalSalesDollars """,conn)
# Out:
#        VendorNo  Brand  TotalSalesQuantity  TotalSalesDollars  \
# 0          8004   5287                   2       9.800000e-01
# 1          9206   2773                   1       9.900000e-01
# 2          3252   3933                   2       1.980000e+00
# 3          3924   9123                   2       1.980000e+00
# 4         10050   3623                   2       1.980000e+00
# ...         ...    ...                 ...                ...
# 11267      3960   3545              135838       4.223108e+06
# 11268      3960   4261              200412       4.475973e+06
# 11269     17035   8068              187140       4.538121e+06
# 11270      4425   3405              160247       4.819073e+06
# 11271      1128   1233              142049       5.101920e+06
#
#        TotalSalesPrice  TotalExciseTax
# 0                 0.98            0.10
# 1                 0.99            0.05
# 2                 0.99            0.10
# 3                 0.99            0.10
# ...

# %%
vendor_sales_summary= pd.read_sql_query(""" WITH FreightSummary AS (
    select
        VendorNumber,
        sum(Freight) as freight_cost
    FROM vendor_invoice 
    GROUP BY VendorNumber
),

PurchaseSummary AS (
    SELECT
       p.VendorNumber,
       p.VendorName,
       p.Brand ,
       p.Description,
       p.PurchasePrice ,
       pp.Volume,
       pp.Price as ActualPrice,
       SUM(p.Quantity) as TotalPurchaseQuantity,
       SUM(p.Dollars) as TotalPurchaseDollars
    FROM purchases as p
    JOIN purchase_prices as pp
       ON p.Brand= pp.Brand
    WHERE p.PurchasePrice>0
    GROUP BY p.VendorNumber,p.VendorName,p.Brand ,p.Description,p.PurchasePrice ,pp.Volume,pp.Price
),

SalesSummary AS(
    SELECT
        VendorNo,
        Brand ,
        SUM(SalesQuantity) AS TotalSalesQuantity,
        SUM(SalesDollars)  AS TotalSalesDollars,
        SUM(SalesPrice) AS TotalSalesPrice,
        SUM(ExciseTax) AS TotalExciseTax
    FROM sales
    GROUP BY VendorNo,Brand 
)

SELECT
       ps.VendorNumber,
       ps.VendorName,
       ps.Brand ,
       ps.Description,
       ps.PurchasePrice ,
       ps.Volume,
       ps.ActualPrice,
       ps.TotalPurchaseQuantity,
       ps.TotalPurchaseDollars,
       ss.TotalSalesQuantity,
       ss.TotalSalesDollars,
       ss.TotalSalesPrice, 
       ss.TotalExciseTax,
       fs.freight_cost 
    FROM  PurchaseSummary ps
    LEFT JOIN  SalesSummary ss
       ON   ps.VendorNumber=ss.VendorNo
       AND ps.Brand= ss.Brand
    LEFT JOIN  FreightSummary fs
       ON  ps.VendorNumber=fs.VendorNumber                
    ORDER BY   ps.TotalPurchaseDollars DESC """,conn)

# %%
vendor_sales_summary
# Out:
#        VendorNumber                   VendorName  Brand  \
# 0              1128  BROWN-FORMAN CORP             1233
# 1              4425        MARTIGNETTI COMPANIES   3405
# 2             17035  PERNOD RICARD USA             8068
# 3              3960  DIAGEO NORTH AMERICA INC      4261
# 4              3960  DIAGEO NORTH AMERICA INC      3545
# ...             ...                          ...    ...
# 10687          9815  WINE GROUP INC                8527
# 10688          8004  SAZERAC CO INC                5683
# 10689          3924  HEAVEN HILL DISTILLERIES      9123
# 10690          3960  DIAGEO NORTH AMERICA INC      6127
# 10691          7245  PROXIMO SPIRITS INC.          3065
#
#                        Description  PurchasePrice Volume  ActualPrice  \
# 0          Jack Daniels No 7 Black          26.27   1750        36.99
# 1            Tito's Handmade Vodka          23.19   1750        28.99
# 2                 Absolut 80 Proof          18.24   1750        24.99
# ...

# %%
vendor_sales_summary.dtypes # has to convert datatype of volume
# Out:
# VendorNumber               int64
# VendorName                object
# Brand                      int64
# Description               object
# PurchasePrice            float64
# Volume                    object
# ActualPrice              float64
# TotalPurchaseQuantity      int64
# TotalPurchaseDollars     float64
# TotalSalesQuantity       float64
# TotalSalesDollars        float64
# TotalSalesPrice          float64
# TotalExciseTax           float64
# freight_cost             float64
# dtype: object

# %%
vendor_sales_summary.isnull().sum() # have to fill null values
# Out:
# VendorNumber               0
# VendorName                 0
# Brand                      0
# Description                0
# PurchasePrice              0
# Volume                     0
# ActualPrice                0
# TotalPurchaseQuantity      0
# TotalPurchaseDollars       0
# TotalSalesQuantity       178
# TotalSalesDollars        178
# TotalSalesPrice          178
# TotalExciseTax           178
# freight_cost               0
# dtype: int64

# %%
vendor_sales_summary.head()
# Out:
#    VendorNumber                   VendorName  Brand              Description  \
# 0          1128  BROWN-FORMAN CORP             1233  Jack Daniels No 7 Black
# 1          4425        MARTIGNETTI COMPANIES   3405    Tito's Handmade Vodka
# 2         17035  PERNOD RICARD USA             8068         Absolut 80 Proof
# 3          3960  DIAGEO NORTH AMERICA INC      4261   Capt Morgan Spiced Rum
# 4          3960  DIAGEO NORTH AMERICA INC      3545          Ketel One Vodka
#
#    PurchasePrice Volume  ActualPrice  TotalPurchaseQuantity  \
# 0          26.27   1750        36.99                 145080
# 1          23.19   1750        28.99                 164038
# 2          18.24   1750        24.99                 187407
# 3          16.17   1750        22.99                 201682
# 4          21.89   1750        29.99                 138109
#
#    TotalPurchaseDollars  TotalSalesQuantity  TotalSalesDollars  \
# 0            3811251.60            142049.0       5.101920e+06
# ...

# %%
vendor_sales_summary["VendorName"].unique() ## many unnecessary spaces are present
# Out:
# array(['BROWN-FORMAN CORP          ', 'MARTIGNETTI COMPANIES',
#        'PERNOD RICARD USA          ', 'DIAGEO NORTH AMERICA INC   ',
#        'BACARDI USA INC            ', 'JIM BEAM BRANDS COMPANY    ',
#        'MAJESTIC FINE WINES        ', 'ULTRA BEVERAGE COMPANY LLP ',
#        'STOLI GROUP,(USA) LLC      ', 'PROXIMO SPIRITS INC.       ',
#        'MOET HENNESSY USA INC      ', 'CAMPARI AMERICA            ',
#        'SAZERAC CO INC             ', 'CONSTELLATION BRANDS INC   ',
#        'M S WALKER INC             ', 'SAZERAC NORTH AMERICA INC. ',
#        'PALM BAY INTERNATIONAL INC ', 'REMY COINTREAU USA INC     ',
#        'SIDNEY FRANK IMPORTING CO  ', 'E & J GALLO WINERY         ',
#        'WILLIAM GRANT & SONS INC   ', 'HEAVEN HILL DISTILLERIES   ',
#        'DISARONNO INTERNATIONAL LLC', 'EDRINGTON AMERICAS         ',
#        'CASTLE BRANDS CORP.        ', 'SOUTHERN WINE & SPIRITS NE ',
#        'STE MICHELLE WINE ESTATES  ', 'TRINCHERO FAMILY ESTATES   ',
# ...

# %%
vendor_sales_summary["Volume"]= vendor_sales_summary["Volume"].astype('float64')

# %%
vendor_sales_summary.dtypes ## datatype of volume has been changed
# Out:
# VendorNumber               int64
# VendorName                object
# Brand                      int64
# Description               object
# PurchasePrice            float64
# Volume                   float64
# ActualPrice              float64
# TotalPurchaseQuantity      int64
# TotalPurchaseDollars     float64
# TotalSalesQuantity       float64
# TotalSalesDollars        float64
# TotalSalesPrice          float64
# TotalExciseTax           float64
# freight_cost             float64
# dtype: object

# %%
vendor_sales_summary.fillna(0, inplace=True)

# %%
vendor_sales_summary.isnull().sum()
# Out:
# VendorNumber             0
# VendorName               0
# Brand                    0
# Description              0
# PurchasePrice            0
# Volume                   0
# ActualPrice              0
# TotalPurchaseQuantity    0
# TotalPurchaseDollars     0
# TotalSalesQuantity       0
# TotalSalesDollars        0
# TotalSalesPrice          0
# TotalExciseTax           0
# freight_cost             0
# dtype: int64

# %%
vendor_sales_summary["VendorName"]=vendor_sales_summary["VendorName"].str.strip()

# %%
vendor_sales_summary["VendorName"].unique()
# Out:
# array(['BROWN-FORMAN CORP', 'MARTIGNETTI COMPANIES', 'PERNOD RICARD USA',
#        'DIAGEO NORTH AMERICA INC', 'BACARDI USA INC',
#        'JIM BEAM BRANDS COMPANY', 'MAJESTIC FINE WINES',
#        'ULTRA BEVERAGE COMPANY LLP', 'STOLI GROUP,(USA) LLC',
#        'PROXIMO SPIRITS INC.', 'MOET HENNESSY USA INC', 'CAMPARI AMERICA',
#        'SAZERAC CO INC', 'CONSTELLATION BRANDS INC', 'M S WALKER INC',
#        'SAZERAC NORTH AMERICA INC.', 'PALM BAY INTERNATIONAL INC',
#        'REMY COINTREAU USA INC', 'SIDNEY FRANK IMPORTING CO',
#        'E & J GALLO WINERY', 'WILLIAM GRANT & SONS INC',
#        'HEAVEN HILL DISTILLERIES', 'DISARONNO INTERNATIONAL LLC',
#        'EDRINGTON AMERICAS', 'CASTLE BRANDS CORP.',
#        'SOUTHERN WINE & SPIRITS NE', 'STE MICHELLE WINE ESTATES',
#        'TRINCHERO FAMILY ESTATES', 'MHW LTD', 'WINE GROUP INC',
#        'PERFECTA WINES', 'LUXCO INC', 'TREASURY WINE ESTATES',
#        'DIAGEO CHATEAU ESTATE WINES', 'SHAW ROSS INT L IMP LTD',
# ...

# %% [markdown]
# ## adding some new columns

# %%
vendor_sales_summary["GrossProfit"] = vendor_sales_summary["TotalSalesDollars"] - vendor_sales_summary["TotalPurchaseDollars"]

# %%
vendor_sales_summary["GrossProfit"].min()
# Out:
# np.float64(-52002.78000000001)

# %%
vendor_sales_summary["ProfitMargin"]=(vendor_sales_summary["GrossProfit"]/ vendor_sales_summary["TotalSalesDollars"])*100

# %%
vendor_sales_summary["StockTurnover"]= vendor_sales_summary["TotalSalesQuantity"]/vendor_sales_summary["TotalPurchaseQuantity"]

# %%
vendor_sales_summary["SalesToPurchaseRatio"]=vendor_sales_summary["TotalSalesDollars"]/vendor_sales_summary["TotalPurchaseDollars"]

# %%
vendor_sales_summary
# Out:
#        VendorNumber                VendorName  Brand  \
# 0              1128         BROWN-FORMAN CORP   1233
# 1              4425     MARTIGNETTI COMPANIES   3405
# 2             17035         PERNOD RICARD USA   8068
# 3              3960  DIAGEO NORTH AMERICA INC   4261
# 4              3960  DIAGEO NORTH AMERICA INC   3545
# ...             ...                       ...    ...
# 10687          9815            WINE GROUP INC   8527
# 10688          8004            SAZERAC CO INC   5683
# 10689          3924  HEAVEN HILL DISTILLERIES   9123
# 10690          3960  DIAGEO NORTH AMERICA INC   6127
# 10691          7245      PROXIMO SPIRITS INC.   3065
#
#                        Description  PurchasePrice  Volume  ActualPrice  \
# 0          Jack Daniels No 7 Black          26.27  1750.0        36.99
# 1            Tito's Handmade Vodka          23.19  1750.0        28.99
# 2                 Absolut 80 Proof          18.24  1750.0        24.99
# ...

# %%
cursor= conn.cursor()

# %%
vendor_sales_summary.columns
# Out:
# Index(['VendorNumber', 'VendorName', 'Brand', 'Description', 'PurchasePrice',
#        'Volume', 'ActualPrice', 'TotalPurchaseQuantity',
#        'TotalPurchaseDollars', 'TotalSalesQuantity', 'TotalSalesDollars',
#        'TotalSalesPrice', 'TotalExciseTax', 'freight_cost', 'GrossProfit',
#        'ProfitMargin', 'StockTurnover', 'SalesToPurchaseRatio'],
#       dtype='object')

# %%
cursor.execute('''CREATE TABLE IF NOT EXISTS vendor_sales_summary (
    
    VendorNumber INT,
    VendorName  VARCHAR(100),
    Brand  INT,
    Description VARCHAR(100),
    PurchasePrice DECIMAL(10,2),
    Volume DECIMAL(10,2),
    ActualPrice DECIMAL(10,2),
    TotalPurchaseQuantity INT,
    TotalPurchaseDollars DECIMAL(15,2),
    TotalSalesQuantity INT,
    TotalSalesDollars DECIMAL(15,2),
    TotalSalesPrice DECIMAL(15,2),
    TotalExciseTax DECIMAL(15,2),
    freight_cost DECIMAL(15,2),
    GrossProfit DECIMAL(15,2),
    ProfitMargin DECIMAL(15,2),
    StockTurnover DECIMAL(15,2),
    SalesToPurchaseRatio DECIMAL(15,2),
    PRIMARY KEY (VendorNumber, Brand)
    )
 ''')

# %%
pd.read_sql_query("select * from vendor_sales_summary",conn)
# Out:
# Empty DataFrame
# Columns: [VendorNumber, VendorName, Brand, Description, PurchasePrice, Volume, ActualPrice, TotalPurchaseQuantity, TotalPurchaseDollars, TotalSalesQuantity, TotalSalesDollars, TotalSalesPrice, TotalExciseTax, freight_cost, GrossProfit, ProfitMargin, StockTurnover, SalesToPurchaseRatio]
# Index: []

# %%
vendor_sales_summary.to_sql('vendor_sales_summary',conn,if_exists="replace",index=False)
# Out:
# 10692

# %%
pd.read_sql_query("select * from vendor_sales_summary",conn)
# Out:
#        VendorNumber                VendorName  Brand  \
# 0              1128         BROWN-FORMAN CORP   1233
# 1              4425     MARTIGNETTI COMPANIES   3405
# 2             17035         PERNOD RICARD USA   8068
# 3              3960  DIAGEO NORTH AMERICA INC   4261
# 4              3960  DIAGEO NORTH AMERICA INC   3545
# ...             ...                       ...    ...
# 10687          9815            WINE GROUP INC   8527
# 10688          8004            SAZERAC CO INC   5683
# 10689          3924  HEAVEN HILL DISTILLERIES   9123
# 10690          3960  DIAGEO NORTH AMERICA INC   6127
# 10691          7245      PROXIMO SPIRITS INC.   3065
#
#                        Description  PurchasePrice  Volume  ActualPrice  \
# 0          Jack Daniels No 7 Black          26.27  1750.0        36.99
# 1            Tito's Handmade Vodka          23.19  1750.0        28.99
# 2                 Absolut 80 Proof          18.24  1750.0        24.99
# ...
